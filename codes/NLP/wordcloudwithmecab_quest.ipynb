# %% [markdown]
# ### Quest
# - 한글 명사만 워드 클라우드 작성
# - 불용어 처리 필요 (한 글자 이하)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\5-21\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\5-21\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\5-21\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\5-21\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\5-21\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\5-21\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\5-21\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\5-21\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\5-21\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\5-21\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\5-21\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\5-21\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud
from mecab import MeCab

# %%
# 한글 문장 리스트
sentences = [
    "오늘 날씨가 좋아서 나들이 가고 싶다.",
    "이 영화는 정말 재미있었어요.",
    "맛있는 음식을 먹으러 갈까요?",
    "운동을 하면 건강에 좋아지는 것 같아요.",
    "공부하기 싫어서 미루고 있어요.",
    "여행 계획을 세우고 있는데 어디로 갈까요?",
    "좋은 책을 읽으면 마음이 편안해져요.",
    "오늘은 친구들과 만나서 재미있게 놀았어요.",
    "새로운 언어를 배우는 것은 어려워도 흥미로워요.",
    "주말에 가족들과 함께 시간을 보내기로 했습니다."
]

# %%
mecab = MeCab()
mecab.nouns(sentences[0])
# Out:
# ['날씨', '나']

# %%
morphs_list = list()
for sentence in sentences : 
    morphs = mecab.nouns(sentence)
    morphs_list = morphs_list + morphs
morphs_list
# Out:
# ['날씨',
#  '나',
#  '영화',
#  '음식',
#  '운동',
#  '건강',
#  '것',
#  '공부',
#  '여행',
#  '계획',
#  '어디',
#  '책',
#  '마음',
#  '편안',
#  '오늘',
#  '친구',
#  '언어',
#  '것',
#  '흥미',
#  '주말',
#  '가족',
#  '시간']

# %%
import re
pattern = r'[것,나]'
text_regex = re.sub(pattern=pattern, repl= '', string=text)
# sub는 replace와 비슷   #params: 변경 대상 , 대상을 대체, 어떤 것을 
text_regex

# %%
morphs_list = [word for word in morphs_list if word not in ['나', '것']]

# %%
from collections import Counter
nouns_count = Counter(morphs_list)
nouns_count
# Out:
# Counter({'날씨': 1,
#          '영화': 1,
#          '음식': 1,
#          '운동': 1,
#          '건강': 1,
#          '공부': 1,
#          '여행': 1,
#          '계획': 1,
#          '어디': 1,
#          '책': 1,
#          '마음': 1,
#          '편안': 1,
#          '오늘': 1,
#          '친구': 1,
#          '언어': 1,
#          '흥미': 1,
#          '주말': 1,
#          '가족': 1,
#          '시간': 1})

# %%
font_path = 'C:/Windows/Fonts/malgun.ttf'
wordCloud = WordCloud(font_path=font_path, background_color='white')
wordCloud.generate_from_frequencies(nouns_count)
wordCloud.words_
# Out:
# {'날씨': 1.0,
#  '영화': 1.0,
#  '음식': 1.0,
#  '운동': 1.0,
#  '건강': 1.0,
#  '공부': 1.0,
#  '여행': 1.0,
#  '계획': 1.0,
#  '어디': 1.0,
#  '책': 1.0,
#  '마음': 1.0,
#  '편안': 1.0,
#  '오늘': 1.0,
#  '친구': 1.0,
#  '언어': 1.0,
#  '흥미': 1.0,
#  '주말': 1.0,
#  '가족': 1.0,
#  '시간': 1.0}

# %%
import matplotlib.pyplot as plt 
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
